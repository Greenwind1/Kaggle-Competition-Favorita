# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Contents" data-toc-modified-id="Contents-1">Contents</a></span></li><li><span><a href="#1.-LOAD-PACKAGES" data-toc-modified-id="1.-LOAD-PACKAGES-2"><center>1. LOAD PACKAGES</center></a></span></li><li><span><a href="#2.-LOAD-DATA" data-toc-modified-id="2.-LOAD-DATA-3"><center>2. LOAD DATA</center></a></span></li><li><span><a href="#-EOF-" data-toc-modified-id="-EOF--4"><center> EOF </center></a></span></li></ul></div>

# %% [markdown]
# ***
# <br>
# <center><font size=7 color=darkgray><b>
# Freesound Audio Tagging 2019
# </b></font></center>
# <br>

# %% [markdown]
# <img src="../fig/header.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# # Contents
# 1. [LOAD PACKAGES](#lp)
# 2. [LOAD DATA](#ld)
#     * [Loading data](#loading_data)

# %% [markdown]
# <a id="lp"></a>
# # <center>1. LOAD PACKAGES</center>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import gc
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(font_scale=1.2)

import warnings

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)
# dir(pd.options.display)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

plt.style.use('ggplot')

import missingno as msno
import datetime as dt
import IPython.display as ipd

from random import sample
from collections import OrderedDict
from random import sample
from datetime import timedelta

# %% [markdown]
# <a id="ld"></a>
# # <center>2. LOAD DATA</center>

# %%
fname = '../input/train_curated/0019ef41.wav'   # Raindrop
ipd.Audio(fname)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # <center> EOF </center>
